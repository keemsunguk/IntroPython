# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as mp
from PIL import Image
# Out:
# UsageError: Line magic function `%pillow` not found.

# %% [markdown]
# ### Loading Image to img2

# %%
img2 = Image.open('/Users/keemsunguk/projects/intro/data/stbug.png')
imgplot = plt.imshow(img2)

# %% [markdown]
# ### Loading image to plot (just get one layer)

# %%
img = mpimg.imread('/Users/keemsunguk/projects/intro/data/stbug.png')
img.shape
img1 = img[:,:,1]
img1plot = plt.imshow(img1, cmap='hot')

# %% [markdown]
# ### Two more colormap

# %%
img1plot = plt.imshow(img1, cmap='Accent')

# %%
img1plot = plt.imshow(img1, cmap='viridis')

# %% [markdown]
# ### Change image size

# %%
img3 = img2.resize( (700, 700), Image.BICUBIC)
img3.show()
img3.save('/Users/keemsunguk/projects/intro/data/hw4-1.png')
# Out:
# /Users/keemsunguk/anaconda3/lib/python3.6/site-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')

# %%
img4 = img2.resize( (100, 100), Image.BICUBIC)
img4.show()
img4.save('/Users/keemsunguk/projects/intro/data/hw4-12.png')
# Out:
# /Users/keemsunguk/anaconda3/lib/python3.6/site-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
