# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as mp

# %%
img = mpimg.imread('/Users/keemsunguk/projects/intro/data/stbug.png')
print(img)
# Out:
# [[[ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   ...,
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]]
#
#  [[ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   ...,
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]]
#
#  [[ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   ...,
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
#   [ 0.27843139  0.43921569  0.29803923  0.        ]
# ...

# %%
img.shape
# Out:
# (682, 1080, 4)

# %%
img1 = img[:,:,0]

# %%
imgplot = plt.imshow(img)

# %%
img1plot = plt.imshow(img1)

# %%
img1plot = plt.imshow(img1, cmap='hot')

# %%
img1plot.set_cmap('nipy_spectral')
img1plot = plt.imshow(img1, cmap='nipy_spectral')
plt.colorbar()

# %%
plt.hist(img1.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
# Out:
# (array([  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           3.44000000e+02,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   6.82000000e+02,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.09500000e+03,
# ...

# %%
imgplot=plt.imshow(img1, clim=(0.5, 0.99))

# %%
fig = plt.figure()
a = fig.add_subplot(2,1,1)
imgplot = plt.imshow(img1)
a.set_title('Before')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='vertical')

a = fig.add_subplot(2,1,2)
imgplot = plt.imshow(img1)
imgplot.set_clim(0.5, 0.7)
a.set_title('After')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='vertical')

# %%
from PIL import Image

# %%
img2 = Image.open('/Users/keemsunguk/projects/intro/data/stinkbug.png')
imgplot = plt.imshow(img2)

# %%
img2.thumbnail( (128, 128), Image.ANTIALIAS)
imgplot = plt.imshow(img2)

# %%
imgplot = plt.imshow(img2, interpolation='bicubic')
