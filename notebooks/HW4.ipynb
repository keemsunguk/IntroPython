# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
in_path = '../data/tr_eikon_eod_data.csv'
data = []
with open(in_path, 'r') as rf:
    text_list = rf.readlines()
    for lin in text_list:
#        print(lin)
        data.append(lin.split(','))
        
    data_df = pd.DataFrame(data[1:], columns=list(data[0]))
    data_df.set_index('Date', inplace=True)
data_df
# Out:
#                         AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N     SPY  \
# Date
# 2010-01-04         30.57282657   30.95   20.88    133.9  173.08  113.33
# 2010-01-05  30.625683660000004   30.96   20.87   134.69  176.14  113.63
# 2010-01-06  30.138541290000003   30.77    20.8   132.25  174.26  113.71
# 2010-01-07  30.082827060000003  30.452    20.6    130.0  177.67  114.19
# 2010-01-08         30.28282686   30.66   20.83   133.52  174.31  114.57
# 2010-01-11  30.015684270000005   30.27   20.95  130.308  171.56  114.73
# 2010-01-12  29.674256040000003   30.07  20.608   127.35  167.82  113.66
# 2010-01-13  30.092827050000004   30.35   20.96   129.11  169.07  114.62
# 2010-01-14  29.918541510000004   30.96   21.48   127.35  168.53  114.93
# 2010-01-15  29.418542010000003   30.86    20.8   127.14  165.21  113.64
# 2010-01-19         30.71996928    31.1   21.05   127.61  166.86  115.06
# 2010-01-20        30.246398325  30.585   21.08   125.78  167.79  113.89
# ...

# %% [markdown]
# ### Q1. While loop:  In the loop, generate integers, check if it is div by 15, if not keep looping if yes print the number, exit.

# %%
my_int = 1
while my_int % 15 != 0:
    my_int = m = random.randint(1,1000)
    print(my_int)
print(my_int, 'is div by 15')
# Out:
# 833
# 711
# 572
# 436
# 321
# 246
# 549
# 691
# 214
# 526
# 79
# 862
# 604
# 390
# 390 is div by 15

# %% [markdown]
# ### Q2. Use lambda and map,, add MSFT and APPL price and print without loop

# %%
print(list(map(lambda x,y : float(x)+float(y), data_df['AAPL.O'].tolist(), data_df['MSFT.O'].tolist())))
# Out:
# [61.52282657, 61.58568366, 60.90854129, 60.534827060000005, 60.94282686, 60.285684270000004, 59.74425604, 60.442827050000005, 60.878541510000005, 60.27854201, 61.81996928, 60.831398325, 59.73454170400001, 57.20997175000001, 58.330685275, 58.91997058, 59.367684588, 57.629971530000006, 55.617543991000005, 56.22854361, 56.439972020000006, 57.091400109999995, 55.27568685, 55.94282922000001, 55.451400840000005, 56.03711483000001, 55.86368641200001, 56.50140019, 56.55568566, 57.407113800000005, 57.52568535, 57.958685296, 57.579971189999995, 57.360828512, 56.481257563, 57.295114192, 57.457114000000004, 57.901399340000005, 58.87568443000001, 58.29568445, 58.36425581, 58.73139847, 59.86604015, 59.92711156, 60.659968140000004, 61.08996788, 61.394253500000005, 61.6413962, 61.267110880000004, 61.43425365, 61.647110839999996, 61.70282505, 61.3399539643, 61.707110750000005, 62.502824520000004, 62.41711009, 62.388539050000006, 62.64568130000001, 62.78853823, 63.462109165, 62.858895000000004, 62.869
# ...

# %% [markdown]
# ### Q3. From the Alice book, replace all Alice with Dylan

# %%
import re
with open('/Users/keemsunguk/projects/intro/data/alice.txt', 'r') as rf:
    alice_book = rf.read()

# %%
sung_book = re.sub('(?i)Alice', 'Sung', alice_book)
print(sung_book[:2000])
# Out:
# Sung's Adventures in Wonderland
#
#                 Sung'S ADVENTURES IN WONDERLAND
#
#                           Lewis Carroll
#
#                THE MILLENNIUM FULCRUM EDITION 3.0
#
#
#
#
#                             CHAPTER I
#
#                       Down the Rabbit-Hole
#
#
#   Sung was beginning to get very tired of sitting by her sister
# on the bank, and of having nothing to do:  once or twice she had
# peeped into the book her sister was reading, but it had no
# pictures or conversations in it, `and what is the use of a book,'
# thought Sung `without pictures or conversation?'
#
#   So she was considering in her own mind (as well as she could,
# for the hot day made her feel very sleepy and stupid), whether
# the pleasure of making a daisy-chain would be worth the trouble
# of getting up and picking the daisies, when suddenly a White
# Rabbit with pink eyes ran close by her.
#
#   There was nothing so VERY remarkable in that; nor did Sung
# ...

# %% [markdown]
# ### Q4. Find the location of all Dylan and count

# %%
for m in re.finditer('Sung', sung_book):
    print(m.start(), m.end())
# Out:
# 0 4
# 49 53
# 263 267
# 523 527
# 914 918
# 1285 1289
# 1627 1631
# 1820 1824
# 2660 2664
# 3172 3176
# 3512 3516
# 4364 4368
# 4736 4740
# 5305 5309
# 5564 5568
# 5961 5965
# 6251 6255
# 6683 6687
# 7099 7103
# 7328 7332
# 7701 7705
# 7893 7897
# 8580 8584
# 8988 8992
# 9395 9399
# 9762 9766
# 10215 10219
# 10689 10693
# 11014 11018
# 11493 11497
# 12005 12009
# 12564 12568
# 12910 12914
# 13028 13032
# 13276 13280
# 13518 13522
# 14208 14212
# 14502 14506
# 16473 16477
# 17045 17049
# 17767 17771
# 18449 18453
# 18902 18906
# 19467 19471
# 19745 19749
# 20141 20145
# 20260 20264
# 20548 20552
# 20791 20795
# 20986 20990
# 21261 21265
# 21668 21672
# 21798 21802
# 22261 22265
# 22694 22698
# 23072 23076
# 23571 23575
# 23815 23819
# 24186 24190
# 25641 25645
# 25685 25689
# 26300 26304
# 27630 27634
# 27751 27755
# 28158 28162
# 28190 28194
# 28457 28461
# 29059 29063
# 29232 29236
# 29291 29295
# 30759 30763
# 30831 30835
# 30969 30973
# 31240 31244
# 31371 31375
# 31918 31922
# ...

# %%
print('The number of occurences inlen(re.findall('Sung', sung_book)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e5f5caba86d2> in <module>()
# ----> 1 print(len(re.findall('Sung', sung_bok)))
#
# NameError: name 'sung_bok' is not defined
