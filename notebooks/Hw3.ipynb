# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_df = pd.read_csv('/Users/keemsunguk/projects/intro/data/tr_eikon_eod_data.csv', index_col=0, parse_dates=True)

# %%
#for ticker in list(data_df.columns):
data_df[list(data_df.columns)].plot(subplots=True, figsize=(5, 20));
#plt.savefig('/Users/keemsunguk/projects/intro/images/spx_volatility.png')

# %%
for ticker in list(data_df.columns):
    data_df[ticker].plot(subplots=True, figsize=(12, 8));
